# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_csv('~/home/bioseq2seq/bioseq2seq_1.PC.EG.rank_0',sep='\t')
#df = pd.read_csv('~/home/bioseq2seq/EDC_1.PC.EG.rank_0',sep='\t')
print(df)
# Out:
#    Unnamed: 0              ID  pct_approx_error   original  mean_sampled  \
# 0           0     XR_681420.2         -0.049507   8.446931      8.252916
# 1           1     XR_244985.3          0.512429  11.211190     11.308528
# 2           2  XR_003032222.1          0.000607   8.412486      8.516545
# 3           3     NR_151716.1         -0.013498   7.583277      7.661037
#
#    best_sampled  optimized
# 0      8.908584   9.587184
# 1     13.078959  13.800370
# 2      9.102470   8.921254
# 3      8.161397   8.180388

# %%
sns.scatterplot(data=df,x='original',y='best_sampled')
X_plot = np.linspace(0, 15, 100)
plt.plot(X_plot,X_plot,linestyle='dashed')
plt.xlabel('NC score best sampled')
#plt.xlabel('NC score original')
plt.ylabel('NC score codon optimized')
# Out:
# Text(0, 0.5, 'NC score codon optimized')
